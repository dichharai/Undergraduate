# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_files
import os
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

# %%
bd = load_files('baise_spamfilter')

# %%
bd.keys()
# Out:
# dict_keys(['DESCR', 'target', 'filenames', 'data', 'target_names'])

# %%
len(bd.data)
# Out:
# 14

# %%
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS

# %%
#ENGLISH_STOP_WORDS

# %%
print(bd.target_names)
# Out:
# ['ham', 'spam']

# %%
print(bd.target_names[bd.target[1]],"\n\n",bd.data[1])
# Out:
# ham
#
#  b'\xef\xbb\xbfThis is just a reminder that today from\xc2\xa05:30 to 7:30\xc2\xa0there will be community members and their children walking through our halls trick or treating.\xc2\xa0\n\nThere will be signs indicating that rooms with pumpkins on them are handing out candy. If you did not sign up to hand out candy but would like to get involved there will be cookie decorating in the second floor lounge.\xc2\xa0\n\nLets make sure that the community members leave our hall with not only candy but a great experience as well.\xc2\xa0\n\nAl\n\n'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(use_idf=False)

# %%
X = vectorizer.fit_transform(bd.data)                            
#X #sparse matrix
#len(vectorizer.get_feature_names()) #670

# %%
for i in range(14):
    for j in range(670):
        if X[i,j] != 0.0:
            print("document = ", i, "score = ",j,X[i,j], vectorizer.get_feature_names()[j])
# Out:
# document =  0 score =  18 0.0426014322842 25
# document =  0 score =  21 0.0426014322842 260
# document =  0 score =  26 0.0426014322842 30
# document =  0 score =  38 0.0426014322842 60
# document =  0 score =  46 0.0426014322842 95
# document =  0 score =  70 0.0426014322842 an
# document =  0 score =  71 0.255608593705 and
# document =  0 score =  76 0.0852028645685 are
# document =  0 score =  78 0.0426014322842 as
# document =  0 score =  91 0.0426014322842 because
# document =  0 score =  93 0.0852028645685 before
# document =  0 score =  95 0.0426014322842 behavior
# document =  0 score =  99 0.0426014322842 better
# document =  0 score =  101 0.0426014322842 big
# document =  0 score =  102 0.0426014322842 billions
# document =  0 score =  104 0.0426014322842 bombs
# document =  0 score =  110 0.0426014322842 buy
# document =  0 score =  152 0.0426014322842 comfort
# document =  0 score =  154 0.170405729137 companies
# document =  0 score =  163 0.0426014322842 consumer
# document =  0 score =  164 0.0852028645685 consumers
# document =  0 score =  168 0.0426014322842 convince
# document =  0 score =  170 0.0426014322842 corporations
# document =  0 score =  172 0.0426014322842 costs
# document =  0 score =  185 0.0426014322842 dear
# document =  0 score =  192 0.0426014322842 develop
# document =  0 score =  196 0.0426014322842 did
# document =  0 score =  197 0.0426014322842 different
# document =  0 score =  198 0.0426014322842 directly
# document =  0 score =  201 0.0426014322842 do
# document =  0 score =  202 0.0852028645685 dollars
# document =  0 score =  212 0.0426014322842 earning
# document =  0 score =  213 0.0426014322842 easier
# document =  0 score =  227 0.0426014322842 extra
# document =  0 score =  235 0.0852028645685 fill
# document =  0 score =  243 0.0426014322842 focus
# document =  0 score =  245 0.170405729137 for
# document =  0 score =  252 0.0852028645685 from
# document =  0 score =  259 0.0852028645685 get
# document =  0 score =  263 0.0852028645685 giving
# document =  0 score =  264 0.0426014322842 gladly
# document =  0 score =  275 0.0426014322842 group
# document =  0 score =  287 0.0852028645685 have
# document =  0 score =  296 0.0426014322842 helps
# document =  0 score =  301 0.0426014322842 home
# document =  0 score =  307 0.0852028645685 hour
# document =  0 score =  315 0.0426014322842 if
# document =  0 score =  319 0.0426014322842 improve
# document =  0 score =  320 0.0852028645685 in
# document =  0 score =  323 0.0426014322842 incredible
# document =  0 score =  325 0.0426014322842 influences
# document =  0 score =  330 0.0426014322842 internet
# document =  0 score =  334 0.0426014322842 is
# document =  0 score =  335 0.170405729137 it
# document =  0 score =  339 0.0852028645685 just
# document =  0 score =  343 0.0426014322842 know
# document =  0 score =  347 0.0426014322842 launch
# document =  0 score =  355 0.0426014322842 life
# document =  0 score =  356 0.0426014322842 like
# document =  0 score =  362 0.0426014322842 lot
# document =  0 score =  370 0.0426014322842 make
# document =  0 score =  371 0.0426014322842 making
# document =  0 score =  372 0.0852028645685 market
# document =  0 score =  377 0.0426014322842 may
# document =  0 score =  381 0.0426014322842 meet
# document =  0 score =  388 0.0426014322842 millions
# document =  0 score =  391 0.0426014322842 minutes
# document =  0 score =  395 0.0852028645685 money
# document =  0 score =  398 0.0426014322842 more
# document =  0 score =  402 0.0426014322842 most
# document =  0 score =  409 0.0426014322842 needs
# document =  0 score =  411 0.0426014322842 new
# document =  0 score =  424 0.213007161421 of
# document =  0 score =  425 0.0426014322842 offer
# document =  0 score =  428 0.170405729137 on
# document =  0 score =  431 0.0426014322842 online
# document =  0 score =  434 0.0426014322842 opinion
# document =  0 score =  435 0.0426014322842 opinions
# document =  0 score =  436 0.0426014322842 opportunity
# document =  0 score =  442 0.0852028645685 out
# document =  0 score =  443 0.0426014322842 over
# document =  0 score =  444 0.0426014322842 own
# document =  0 score =  446 0.0852028645685 paid
# document =  0 score =  447 0.0426014322842 panels
# document =  0 score =  449 0.0426014322842 participating
# document =  0 score =  450 0.0426014322842 participation
# document =  0 score =  452 0.0852028645685 pay
# document =  0 score =  455 0.0426014322842 people
# document =  0 score =  456 0.0852028645685 per
# document =  0 score =  468 0.0426014322842 policies
# document =  0 score =  471 0.0426014322842 possible
# document =  0 score =  478 0.0426014322842 product
# document =  0 score =  479 0.170405729137 products
# document =  0 score =  496 0.0426014322842 really
# document =  0 score =  506 0.0426014322842 released
# document =  0 score =  516 0.0426014322842 research
# document =  0 score =  537 0.0426014322842 seem
# document =  0 score =  540 0.0426014322842 sent
# document =  0 score =  542 0.127804296853 services
# document =  0 score =  549 0.0852028645685 simple
# document =  0 score =  553 0.0426014322842 spend
# document =  0 score =  563 0.0426014322842 student
# document =  0 score =  570 0.127804296853 surveys
# document =  0 score =  580 0.0426014322842 testing
# document =  0 score =  584 0.0426014322842 that
# document =  0 score =  585 0.255608593705 the
# document =  0 score =  586 0.0852028645685 their
# document =  0 score =  587 0.0426014322842 them
# document =  0 score =  590 0.170405729137 they
# document =  0 score =  600 0.468615755127 to
# document =  0 score =  603 0.0426014322842 totally
# document =  0 score =  613 0.0426014322842 trying
# document =  0 score =  618 0.0426014322842 unaware
# document =  0 score =  620 0.0426014322842 understanding
# document =  0 score =  640 0.0426014322842 way
# document =  0 score =  653 0.0852028645685 will
# document =  0 score =  663 0.0426014322842 would
# document =  0 score =  666 0.0426014322842 year
# document =  0 score =  668 0.213007161421 you
# document =  0 score =  669 0.213007161421 your
# document =  1 score =  26 0.169030850946 30
# document =  1 score =  61 0.0845154254729 al
# document =  1 score =  71 0.0845154254729 and
# document =  1 score =  76 0.0845154254729 are
# document =  1 score =  78 0.0845154254729 as
# document =  1 score =  90 0.253546276419 be
# document =  1 score =  109 0.169030850946 but
# document =  1 score =  119 0.253546276419 candy
# document =  1 score =  135 0.0845154254729 children
# document =  1 score =  153 0.169030850946 community
# document =  1 score =  169 0.0845154254729 cookie
# document =  1 score =  188 0.0845154254729 decorating
# document =  1 score =  196 0.0845154254729 did
# document =  1 score =  225 0.0845154254729 experience
# document =  1 score =  241 0.0845154254729 floor
# document =  1 score =  252 0.0845154254729 from
# document =  1 score =  259 0.0845154254729 get
# document =  1 score =  274 0.0845154254729 great
# document =  1 score =  279 0.0845154254729 hall
# document =  1 score =  281 0.0845154254729 halls
# document =  1 score =  283 0.0845154254729 hand
# document =  1 score =  284 0.0845154254729 handing
# document =  1 score =  315 0.0845154254729 if
# document =  1 score =  320 0.0845154254729 in
# document =  1 score =  324 0.0845154254729 indicating
# document =  1 score =  332 0.0845154254729 involved
# document =  1 score =  334 0.0845154254729 is
# document =  1 score =  339 0.0845154254729 just
# document =  1 score =  350 0.0845154254729 leave
# document =  1 score =  353 0.0845154254729 lets
# document =  1 score =  356 0.0845154254729 like
# document =  1 score =  363 0.0845154254729 lounge
# document =  1 score =  370 0.0845154254729 make
# document =  1 score =  384 0.169030850946 members
# document =  1 score =  415 0.169030850946 not
# document =  1 score =  428 0.0845154254729 on
# document =  1 score =  432 0.0845154254729 only
# document =  1 score =  438 0.0845154254729 or
# document =  1 score =  441 0.169030850946 our
# document =  1 score =  442 0.169030850946 out
# document =  1 score =  489 0.0845154254729 pumpkins
# document =  1 score =  507 0.0845154254729 reminder
# document =  1 score =  523 0.0845154254729 rooms
# document =  1 score =  533 0.0845154254729 second
# document =  1 score =  547 0.0845154254729 sign
# document =  1 score =  548 0.0845154254729 signs
# document =  1 score =  569 0.0845154254729 sure
# document =  1 score =  584 0.253546276419 that
# document =  1 score =  585 0.169030850946 the
# document =  1 score =  586 0.0845154254729 their
# document =  1 score =  587 0.0845154254729 them
# document =  1 score =  589 0.253546276419 there
# document =  1 score =  593 0.0845154254729 this
# document =  1 score =  596 0.0845154254729 through
# document =  1 score =  600 0.253546276419 to
# document =  1 score =  601 0.0845154254729 today
# document =  1 score =  610 0.0845154254729 treating
# document =  1 score =  611 0.0845154254729 trick
# document =  1 score =  623 0.0845154254729 up
# document =  1 score =  635 0.0845154254729 walking
# document =  1 score =  648 0.0845154254729 well
# document =  1 score =  653 0.253546276419 will
# document =  1 score =  658 0.169030850946 with
# document =  1 score =  663 0.0845154254729 would
# document =  1 score =  668 0.0845154254729 you
# document =  2 score =  28 0.0575435337648 335
# document =  2 score =  29 0.0575435337648 340
# document =  2 score =  63 0.11508706753 all
# document =  2 score =  71 0.230174135059 and
# document =  2 score =  74 0.0575435337648 anytime
# document =  2 score =  90 0.0575435337648 be
# document =  2 score =  111 0.11508706753 by
# document =  2 score =  119 0.0575435337648 candy
# document =  2 score =  123 0.172630601295 career
# document =  2 score =  126 0.172630601295 center
# document =  2 score =  166 0.0575435337648 continue
# document =  2 score =  171 0.0575435337648 correct
# document =  2 score =  186 0.0575435337648 december
# document =  2 score =  201 0.0575435337648 do
# document =  2 score =  204 0.0575435337648 done
# document =  2 score =  222 0.0575435337648 everyone
# document =  2 score =  245 0.11508706753 for
# document =  2 score =  254 0.11508706753 fun
# document =  2 score =  257 0.0575435337648 game
# document =  2 score =  268 0.0575435337648 going
# document =  2 score =  274 0.0575435337648 great
# document =  2 score =  276 0.172630601295 guess
# document =  2 score =  277 0.0575435337648 guessing
# document =  2 score =  278 0.0575435337648 had
# document =  2 score =  280 0.0575435337648 halloween
# document =  2 score =  287 0.0575435337648 have
# document =  2 score =  290 0.0575435337648 hear
# document =  2 score =  294 0.0575435337648 help
# document =  2 score =  305 0.0575435337648 hope
# document =  2 score =  308 0.0575435337648 how
# document =  2 score =  320 0.172630601295 in
# document =  2 score =  331 0.11508706753 into
# document =  2 score =  334 0.0575435337648 is
# document =  2 score =  346 0.0575435337648 late
# document =  2 score =  358 0.0575435337648 lives
# document =  2 score =  364 0.0575435337648 love
# document =  2 score =  412 0.0575435337648 next
# document =  2 score =  418 0.0575435337648 november
# document =  2 score =  420 0.11508706753 number
# document =  2 score =  424 0.172630601295 of
# document =  2 score =  428 0.0575435337648 on
# document =  2 score =  441 0.0575435337648 our
# document =  2 score =  459 0.0575435337648 pieces
# document =  2 score =  460 0.0575435337648 pierce
# document =  2 score =  488 0.11508706753 pumpkin
# document =  2 score =  524 0.0575435337648 ryan
# document =  2 score =  560 0.11508706753 stop
# document =  2 score =  561 0.0575435337648 stopping
# document =  2 score =  569 0.0575435337648 sure
# document =  2 score =  574 0.0575435337648 taking
# document =  2 score =  582 0.0575435337648 thank
# document =  2 score =  585 0.632978871413 the
# document =  2 score =  598 0.0575435337648 timates
# document =  2 score =  599 0.0575435337648 time
# document =  2 score =  600 0.172630601295 to
# document =  2 score =  629 0.0575435337648 variations
# document =  2 score =  638 0.11508706753 was
# document =  2 score =  639 0.0575435337648 watching
# document =  2 score =  641 0.230174135059 we
# document =  2 score =  645 0.0575435337648 weekend
# document =  2 score =  649 0.0575435337648 were
# document =  2 score =  650 0.0575435337648 what
# document =  2 score =  651 0.0575435337648 when
# document =  2 score =  653 0.11508706753 will
# document =  2 score =  654 0.0575435337648 winner
# document =  2 score =  658 0.11508706753 with
# document =  2 score =  668 0.11508706753 you
# document =  2 score =  669 0.0575435337648 your
# document =  3 score =  17 0.04472135955 24
# document =  3 score =  33 0.04472135955 48
# document =  3 score =  38 0.04472135955 60
# document =  3 score =  58 0.04472135955 again
# document =  3 score =  63 0.0894427191 all
# document =  3 score =  65 0.04472135955 also
# document =  3 score =  70 0.04472135955 an
# document =  3 score =  71 0.4472135955 and
# document =  3 score =  73 0.04472135955 any
# document =  3 score =  76 0.04472135955 are
# document =  3 score =  78 0.13416407865 as
# document =  3 score =  81 0.0894427191 assure
# document =  3 score =  84 0.04472135955 audio
# document =  3 score =  85 0.04472135955 audios
# document =  3 score =  90 0.13416407865 be
# document =  3 score =  92 0.04472135955 been
# document =  3 score =  115 0.04472135955 call
# document =  3 score =  116 0.1788854382 can
# document =  3 score =  143 0.04472135955 client
# document =  3 score =  144 0.04472135955 clients
# document =  3 score =  157 0.04472135955 completed
# document =  3 score =  161 0.0894427191 confidentiality
# document =  3 score =  167 0.04472135955 convenience
# document =  3 score =  173 0.04472135955 could
# document =  3 score =  189 0.04472135955 deleted
# document =  3 score =  199 0.04472135955 discuss
# document =  3 score =  201 0.0894427191 do
# document =  3 score =  225 0.04472135955 experience
# document =  3 score =  245 0.04472135955 for
# document =  3 score =  246 0.0894427191 forward
# document =  3 score =  252 0.13416407865 from
# document =  3 score =  256 0.04472135955 further
# document =  3 score =  262 0.04472135955 gina
# document =  3 score =  270 0.04472135955 good
# document =  3 score =  287 0.0894427191 have
# document =  3 score =  291 0.04472135955 hearing
# document =  3 score =  293 0.04472135955 hello
# document =  3 score =  310 0.04472135955 hrs
# document =  3 score =  315 0.13416407865 if
# document =  3 score =  318 0.04472135955 importantly
# document =  3 score =  327 0.0894427191 information
# document =  3 score =  334 0.22360679775 is
# document =  3 score =  335 0.04472135955 it
# document =  3 score =  343 0.04472135955 know
# document =  3 score =  352 0.04472135955 let
# document =  3 score =  361 0.04472135955 looking
# document =  3 score =  365 0.04472135955 low
# document =  3 score =  368 0.04472135955 made
# document =  3 score =  373 0.04472135955 materials
# document =  3 score =  378 0.04472135955 me
# document =  3 score =  379 0.04472135955 means
# document =  3 score =  390 0.04472135955 minute
# document =  3 score =  392 0.04472135955 mode
# document =  3 score =  402 0.04472135955 most
# document =  3 score =  407 0.04472135955 nda
# document =  3 score =  424 0.31304951685 of
# document =  3 score =  425 0.04472135955 offer
# document =  3 score =  429 0.04472135955 once
# document =  3 score =  432 0.04472135955 only
# document =  3 score =  438 0.04472135955 or
# document =  3 score =  440 0.04472135955 other
# document =  3 score =  441 0.0894427191 our
# document =  3 score =  443 0.04472135955 over
# document =  3 score =  453 0.0894427191 payment
# document =  3 score =  454 0.04472135955 paypal
# document =  3 score =  456 0.0894427191 per
# document =  3 score =  484 0.04472135955 proprietary
# document =  3 score =  491 0.0894427191 quality
# document =  3 score =  494 0.04472135955 rate
# document =  3 score =  499 0.04472135955 regards
# document =  3 score =  514 0.04472135955 required
# document =  3 score =  515 0.04472135955 requirements
# document =  3 score =  518 0.04472135955 returned
# document =  3 score =  525 0.0894427191 sample
# document =  3 score =  527 0.0894427191 satisfaction
# document =  3 score =  528 0.04472135955 satisfied
# document =  3 score =  545 0.04472135955 several
# document =  3 score =  547 0.04472135955 sign
# document =  3 score =  550 0.04472135955 smith
# document =  3 score =  551 0.04472135955 so
# document =  3 score =  552 0.0894427191 soon
# document =  3 score =  567 0.04472135955 supporting
# document =  3 score =  571 0.04472135955 systems
# document =  3 score =  573 0.04472135955 take
# document =  3 score =  585 0.31304951685 the
# document =  3 score =  586 0.04472135955 their
# document =  3 score =  588 0.04472135955 then
# document =  3 score =  589 0.04472135955 there
# document =  3 score =  593 0.04472135955 this
# document =  3 score =  599 0.0894427191 time
# document =  3 score =  600 0.1788854382 to
# document =  3 score =  606 0.04472135955 transcribed
# document =  3 score =  607 0.04472135955 transcript
# document =  3 score =  608 0.13416407865 transcription
# document =  3 score =  609 0.04472135955 transfer
# document =  3 score =  625 0.04472135955 usd
# document =  3 score =  632 0.04472135955 very
# document =  3 score =  641 0.04472135955 we
# document =  3 score =  650 0.0894427191 what
# document =  3 score =  656 0.04472135955 wire
# document =  3 score =  658 0.0894427191 with
# document =  3 score =  659 0.04472135955 within
# document =  3 score =  661 0.1788854382 work
# document =  3 score =  662 0.04472135955 working
# document =  3 score =  667 0.04472135955 years
# document =  3 score =  668 0.2683281573 you
# document =  3 score =  669 0.0894427191 your
# document =  4 score =  26 0.046373889576 30
# document =  4 score =  34 0.046373889576 50
# document =  4 score =  67 0.046373889576 amazon
# document =  4 score =  71 0.370991116608 and
# document =  4 score =  76 0.046373889576 are
# document =  4 score =  78 0.092747779152 as
# document =  4 score =  80 0.046373889576 assistant
# document =  4 score =  82 0.046373889576 at
# document =  4 score =  88 0.046373889576 back
# document =  4 score =  89 0.139121668728 background
# document =  4 score =  90 0.139121668728 be
# document =  4 score =  98 0.046373889576 best
# document =  4 score =  107 0.092747779152 broad
# document =  4 score =  116 0.092747779152 can
# document =  4 score =  121 0.046373889576 cards
# document =  4 score =  130 0.046373889576 challenges
# document =  4 score =  132 0.046373889576 cheers
# document =  4 score =  136 0.046373889576 choice
# document =  4 score =  137 0.046373889576 choose
# document =  4 score =  150 0.046373889576 college
# document =  4 score =  151 0.046373889576 com
# document =  4 score =  156 0.092747779152 competition
# document =  4 score =  159 0.046373889576 computer
# document =  4 score =  165 0.046373889576 contact
# document =  4 score =  174 0.046373889576 courses
# document =  4 score =  178 0.046373889576 current
# document =  4 score =  182 0.046373889576 day
# document =  4 score =  184 0.046373889576 deadline
# document =  4 score =  187 0.046373889576 decorah
# document =  4 score =  203 0.046373889576 don
# document =  4 score =  208 0.046373889576 each
# document =  4 score =  209 0.046373889576 early
# document =  4 score =  214 0.046373889576 edu
# document =  4 score =  219 0.046373889576 even
# document =  4 score =  220 0.046373889576 evening
# document =  4 score =  221 0.046373889576 events
# document =  4 score =  233 0.046373889576 fey
# document =  4 score =  234 0.046373889576 feyky01
# document =  4 score =  238 0.046373889576 find
# document =  4 score =  244 0.046373889576 food
# document =  4 score =  245 0.046373889576 for
# document =  4 score =  249 0.092747779152 free
# document =  4 score =  251 0.046373889576 friendly
# document =  4 score =  252 0.046373889576 from
# document =  4 score =  254 0.046373889576 fun
# document =  4 score =  259 0.092747779152 get
# document =  4 score =  261 0.046373889576 gift
# document =  4 score =  285 0.092747779152 has
# document =  4 score =  287 0.139121668728 have
# document =  4 score =  295 0.046373889576 helpful
# document =  4 score =  306 0.046373889576 hosting
# document =  4 score =  309 0.046373889576 however
# document =  4 score =  312 0.046373889576 ia
# document =  4 score =  314 0.046373889576 ideal
# document =  4 score =  315 0.139121668728 if
# document =  4 score =  320 0.23186944788 in
# document =  4 score =  329 0.092747779152 interested
# document =  4 score =  333 0.046373889576 iowa
# document =  4 score =  334 0.185495558304 is
# document =  4 score =  344 0.092747779152 kyle
# document =  4 score =  345 0.046373889576 last
# document =  4 score =  346 0.046373889576 late
# document =  4 score =  350 0.046373889576 leave
# document =  4 score =  356 0.046373889576 like
# document =  4 score =  366 0.139121668728 luther
# document =  4 score =  374 0.046373889576 math
# document =  4 score =  375 0.046373889576 mathematical
# document =  4 score =  376 0.046373889576 mathematics
# document =  4 score =  378 0.046373889576 me
# document =  4 score =  383 0.046373889576 member
# document =  4 score =  387 0.092747779152 might
# document =  4 score =  393 0.092747779152 modeling
# document =  4 score =  400 0.046373889576 morning
# document =  4 score =  418 0.046373889576 november
# document =  4 score =  422 0.046373889576 october
# document =  4 score =  423 0.046373889576 odes
# document =  4 score =  424 0.185495558304 of
# document =  4 score =  428 0.046373889576 on
# document =  4 score =  438 0.046373889576 or
# document =  4 score =  449 0.046373889576 participating
# document =  4 score =  455 0.046373889576 people
# document =  4 score =  465 0.046373889576 please
# document =  4 score =  471 0.046373889576 possible
# document =  4 score =  472 0.046373889576 presentation
# document =  4 score =  474 0.046373889576 probability
# document =  4 score =  475 0.046373889576 problems
# document =  4 score =  480 0.046373889576 professor
# document =  4 score =  498 0.046373889576 received
# document =  4 score =  503 0.046373889576 registration
# document =  4 score =  504 0.046373889576 related
# document =  4 score =  505 0.046373889576 relatively
# document =  4 score =  529 0.046373889576 saturday
# document =  4 score =  532 0.046373889576 science
# document =  4 score =  551 0.046373889576 so
# document =  4 score =  552 0.046373889576 soon
# document =  4 score =  557 0.046373889576 statistices
# document =  4 score =  559 0.046373889576 still
# document =  4 score =  575 0.139121668728 team
# document =  4 score =  576 0.046373889576 teams
# document =  4 score =  584 0.092747779152 that
# document =  4 score =  585 0.417365006184 the
# document =  4 score =  592 0.046373889576 think
# document =  4 score =  593 0.046373889576 this
# document =  4 score =  595 0.046373889576 three
# document =  4 score =  600 0.185495558304 to
# document =  4 score =  616 0.092747779152 two
# document =  4 score =  621 0.046373889576 university
# document =  4 score =  623 0.046373889576 up
# document =  4 score =  628 0.046373889576 usually
# document =  4 score =  641 0.046373889576 we
# document =  4 score =  655 0.046373889576 winning
# document =  4 score =  660 0.046373889576 won
# document =  4 score =  663 0.092747779152 would
# document =  4 score =  667 0.046373889576 years
# document =  4 score =  668 0.324617227032 you
# document =  5 score =  0 0.152498570333 0635
# document =  5 score =  5 0.152498570333 19101
# document =  5 score =  30 0.152498570333 37635
# document =  5 score =  41 0.152498570333 81361
# document =  5 score =  55 0.152498570333 addressing
# document =  5 score =  141 0.152498570333 click
# document =  5 score =  151 0.304997140665 com
# document =  5 score =  163 0.152498570333 consumer
# document =  5 score =  232 0.304997140665 ferrusmedia
# document =  5 score =  237 0.152498570333 financial
# document =  5 score =  252 0.152498570333 from
# document =  5 score =  259 0.152498570333 get
# document =  5 score =  260 0.152498570333 getting
# document =  5 score =  269 0.152498570333 gone
# document =  5 score =  303 0.152498570333 homeowners
# document =  5 score =  311 0.304997140665 http
# document =  5 score =  326 0.152498570333 info
# document =  5 score =  359 0.152498570333 loans
# document =  5 score =  398 0.152498570333 more
# document =  5 score =  401 0.152498570333 mortgage
# document =  5 score =  409 0.152498570333 needs
# document =  5 score =  424 0.152498570333 of
# document =  5 score =  426 0.152498570333 office
# document =  5 score =  445 0.152498570333 pa
# document =  5 score =  457 0.152498570333 philly
# document =  5 score =  512 0.152498570333 reports
# document =  5 score =  519 0.152498570333 reverse
# document =  5 score =  568 0.152498570333 supportpostal
# document =  5 score =  585 0.152498570333 the
# document =  5 score =  601 0.152498570333 today
# document =  5 score =  665 0.304997140665 www
# document =  6 score =  3 0.0909090909091 150
# document =  6 score =  4 0.0909090909091 1620
# document =  6 score =  7 0.0909090909091 1hr
# document =  6 score =  12 0.0909090909091 203
# document =  6 score =  14 0.0909090909091 214
# document =  6 score =  15 0.0909090909091 230
# document =  6 score =  23 0.0909090909091 270
# document =  6 score =  27 0.0909090909091 30mins
# document =  6 score =  31 0.0909090909091 3r4
# document =  6 score =  36 0.0909090909091 55
# document =  6 score =  42 0.0909090909091 864
# document =  6 score =  43 0.0909090909091 8864
# document =  6 score =  59 0.0909090909091 agents
# document =  6 score =  62 0.0909090909091 alberta
# document =  6 score =  70 0.0909090909091 an
# document =  6 score =  71 0.181818181818 and
# document =  6 score =  76 0.0909090909091 are
# document =  6 score =  78 0.0909090909091 as
# document =  6 score =  88 0.0909090909091 back
# document =  6 score =  90 0.0909090909091 be
# document =  6 score =  92 0.0909090909091 been
# document =  6 score =  100 0.0909090909091 between
# document =  6 score =  114 0.0909090909091 calgary
# document =  6 score =  116 0.0909090909091 can
# document =  6 score =  117 0.0909090909091 canada
# document =  6 score =  150 0.0909090909091 college
# document =  6 score =  151 0.0909090909091 com
# document =  6 score =  173 0.0909090909091 could
# document =  6 score =  190 0.0909090909091 department
# document =  6 score =  191 0.0909090909091 details
# document =  6 score =  201 0.181818181818 do
# document =  6 score =  210 0.0909090909091 earn
# document =  6 score =  230 0.0909090909091 fax
# document =  6 score =  242 0.0909090909091 fluor
# document =  6 score =  245 0.181818181818 for
# document =  6 score =  252 0.0909090909091 from
# document =  6 score =  256 0.0909090909091 further
# document =  6 score =  258 0.0909090909091 george
# document =  6 score =  287 0.0909090909091 have
# document =  6 score =  288 0.0909090909091 having
# document =  6 score =  299 0.0909090909091 hi
# document =  6 score =  308 0.0909090909091 how
# document =  6 score =  311 0.0909090909091 http
# document =  6 score =  315 0.0909090909091 if
# document =  6 score =  320 0.0909090909091 in
# document =  6 score =  327 0.0909090909091 information
# document =  6 score =  329 0.0909090909091 interested
# document =  6 score =  337 0.0909090909091 job
# document =  6 score =  342 0.0909090909091 kindly
# document =  6 score =  343 0.0909090909091 know
# document =  6 score =  361 0.0909090909091 looking
# document =  6 score =  398 0.0909090909091 more
# document =  6 score =  399 0.0909090909091 morlidge
# document =  6 score =  408 0.0909090909091 need
# document =  6 score =  431 0.0909090909091 online
# document =  6 score =  436 0.0909090909091 opportunity
# document =  6 score =  441 0.0909090909091 our
# document =  6 score =  448 0.181818181818 part
# document =  6 score =  464 0.0909090909091 plaza
# document =  6 score =  476 0.0909090909091 proceed
# document =  6 score =  477 0.181818181818 procurement
# document =  6 score =  563 0.0909090909091 student
# document =  6 score =  566 0.0909090909091 sunpark
# document =  6 score =  572 0.0909090909091 t2x
# document =  6 score =  575 0.0909090909091 team
# document =  6 score =  577 0.0909090909091 tel
# document =  6 score =  584 0.0909090909091 that
# document =  6 score =  585 0.0909090909091 the
# document =  6 score =  589 0.0909090909091 there
# document =  6 score =  593 0.0909090909091 this
# document =  6 score =  599 0.181818181818 time
# document =  6 score =  600 0.0909090909091 to
# document =  6 score =  642 0.0909090909091 website
# document =  6 score =  646 0.0909090909091 weekly
# document =  6 score =  658 0.0909090909091 with
# document =  6 score =  662 0.0909090909091 working
# document =  6 score =  664 0.0909090909091 write
# document =  6 score =  665 0.0909090909091 www
# document =  6 score =  668 0.454545454545 you
# document =  7 score =  66 0.267261241912 am
# document =  7 score =  71 0.267261241912 and
# document =  7 score =  75 0.133630620956 apply
# document =  7 score =  76 0.133630620956 are
# document =  7 score =  116 0.133630620956 can
# document =  7 score =  159 0.133630620956 computer
# document =  7 score =  193 0.133630620956 developer
# document =  7 score =  194 0.133630620956 development
# document =  7 score =  201 0.267261241912 do
# document =  7 score =  225 0.133630620956 experience
# document =  7 score =  245 0.267261241912 for
# document =  7 score =  287 0.133630620956 have
# document =  7 score =  299 0.133630620956 hi
# document =  7 score =  308 0.133630620956 how
# document =  7 score =  320 0.133630620956 in
# document =  7 score =  329 0.133630620956 interested
# document =  7 score =  335 0.133630620956 it
# document =  7 score =  343 0.133630620956 know
# document =  7 score =  352 0.133630620956 let
# document =  7 score =  356 0.133630620956 like
# document =  7 score =  361 0.133630620956 looking
# document =  7 score =  369 0.133630620956 major
# document =  7 score =  374 0.133630620956 math
# document =  7 score =  378 0.133630620956 me
# document =  7 score =  389 0.133630620956 minor
# document =  7 score =  406 0.133630620956 nave
# document =  7 score =  417 0.133630620956 notice
# document =  7 score =  428 0.133630620956 on
# document =  7 score =  470 0.133630620956 position
# document =  7 score =  480 0.133630620956 professor
# document =  7 score =  482 0.133630620956 programming
# document =  7 score =  496 0.133630620956 really
# document =  7 score =  530 0.133630620956 saw
# document =  7 score =  532 0.133630620956 science
# document =  7 score =  539 0.133630620956 senior
# document =  7 score =  563 0.133630620956 student
# document =  7 score =  583 0.133630620956 thanks
# document =  7 score =  584 0.133630620956 that
# document =  7 score =  585 0.133630620956 the
# document =  7 score =  642 0.267261241912 website
# document =  7 score =  668 0.133630620956 you
# document =  8 score =  39 0.0508986598559 68
# document =  8 score =  48 0.0508986598559 acceptance
# document =  8 score =  49 0.0508986598559 access
# document =  8 score =  52 0.0508986598559 across
# document =  8 score =  54 0.0508986598559 additional
# document =  8 score =  60 0.0508986598559 aid
# document =  8 score =  63 0.101797319712 all
# document =  8 score =  64 0.0508986598559 allocation
# document =  8 score =  68 0.0508986598559 american
# document =  8 score =  69 0.0508986598559 americans
# document =  8 score =  71 0.203594639424 and
# document =  8 score =  75 0.0508986598559 apply
# document =  8 score =  76 0.0508986598559 are
# document =  8 score =  79 0.0508986598559 assistance
# document =  8 score =  90 0.0508986598559 be
# document =  8 score =  93 0.0508986598559 before
# document =  8 score =  96 0.0508986598559 below
# document =  8 score =  97 0.0508986598559 benefits
# document =  8 score =  103 0.101797319712 bills
# document =  8 score =  116 0.0508986598559 can
# document =  8 score =  120 0.0508986598559 card
# document =  8 score =  122 0.0508986598559 care
# document =  8 score =  124 0.0508986598559 cause
# document =  8 score =  129 0.0508986598559 chai
# document =  8 score =  138 0.0508986598559 city
# document =  8 score =  155 0.0508986598559 compatible
# document =  8 score =  175 0.0508986598559 covers
# document =  8 score =  176 0.0508986598559 credit
# document =  8 score =  195 0.0508986598559 dichha
# document =  8 score =  200 0.0508986598559 distress
# document =  8 score =  201 0.101797319712 do
# document =  8 score =  203 0.0508986598559 don
# document =  8 score =  217 0.0508986598559 entire
# document =  8 score =  218 0.0508986598559 error
# document =  8 score =  229 0.0508986598559 family
# document =  8 score =  231 0.0508986598559 feel
# document =  8 score =  237 0.101797319712 financial
# document =  8 score =  238 0.0508986598559 find
# document =  8 score =  245 0.305391959136 for
# document =  8 score =  252 0.0508986598559 from
# document =  8 score =  255 0.0508986598559 funds
# document =  8 score =  259 0.101797319712 get
# document =  8 score =  260 0.0508986598559 getting
# document =  8 score =  266 0.0508986598559 go
# document =  8 score =  269 0.0508986598559 gone
# document =  8 score =  271 0.0508986598559 gov
# document =  8 score =  272 0.101797319712 government
# document =  8 score =  273 0.101797319712 grants
# document =  8 score =  287 0.0508986598559 have
# document =  8 score =  289 0.101797319712 health
# document =  8 score =  294 0.0508986598559 help
# document =  8 score =  298 0.25449329928 here
# document =  8 score =  300 0.101797319712 hk
# document =  8 score =  315 0.0508986598559 if
# document =  8 score =  320 0.101797319712 in
# document =  8 score =  322 0.101797319712 income
# document =  8 score =  326 0.0508986598559 info
# document =  8 score =  327 0.0508986598559 information
# document =  8 score =  328 0.0508986598559 insurance
# document =  8 score =  334 0.152695979568 is
# document =  8 score =  336 0.0508986598559 its
# document =  8 score =  338 0.0508986598559 johnson
# document =  8 score =  348 0.0508986598559 law
# document =  8 score =  352 0.0508986598559 let
# document =  8 score =  357 0.0508986598559 live
# document =  8 score =  365 0.152695979568 low
# document =  8 score =  369 0.0508986598559 major
# document =  8 score =  380 0.0508986598559 medical
# document =  8 score =  381 0.0508986598559 meet
# document =  8 score =  385 0.0508986598559 message
# document =  8 score =  391 0.0508986598559 minutes
# document =  8 score =  395 0.203594639424 money
# document =  8 score =  397 0.0508986598559 monthly
# document =  8 score =  403 0.0508986598559 much
# document =  8 score =  409 0.0508986598559 needs
# document =  8 score =  410 0.0508986598559 never
# document =  8 score =  411 0.0508986598559 new
# document =  8 score =  414 0.0508986598559 non
# document =  8 score =  419 0.0508986598559 now
# document =  8 score =  424 0.0508986598559 of
# document =  8 score =  428 0.0508986598559 on
# document =  8 score =  432 0.0508986598559 only
# document =  8 score =  442 0.0508986598559 out
# document =  8 score =  452 0.101797319712 pay
# document =  8 score =  458 0.0508986598559 phone
# document =  8 score =  465 0.0508986598559 please
# document =  8 score =  481 0.101797319712 program
# document =  8 score =  483 0.0508986598559 programs
# document =  8 score =  485 0.0508986598559 provide
# document =  8 score =  490 0.0508986598559 qualify
# document =  8 score =  494 0.0508986598559 rate
# document =  8 score =  498 0.0508986598559 received
# document =  8 score =  508 0.0508986598559 rent
# document =  8 score =  509 0.0508986598559 repaid
# document =  8 score =  510 0.0508986598559 repayable
# document =  8 score =  515 0.0508986598559 requirements
# document =  8 score =  543 0.0508986598559 settle
# document =  8 score =  544 0.0508986598559 settlement
# document =  8 score =  551 0.0508986598559 so
# document =  8 score =  555 0.101797319712 start
# document =  8 score =  564 0.101797319712 students
# document =  8 score =  579 0.0508986598559 test
# document =  8 score =  584 0.0508986598559 that
# document =  8 score =  585 0.305391959136 the
# document =  8 score =  587 0.0508986598559 them
# document =  8 score =  589 0.0508986598559 there
# document =  8 score =  593 0.25449329928 this
# document =  8 score =  594 0.0508986598559 though
# document =  8 score =  600 0.152695979568 to
# document =  8 score =  622 0.101797319712 unsubscribe
# document =  8 score =  624 0.101797319712 us
# document =  8 score =  636 0.0508986598559 wan
# document =  8 score =  641 0.0508986598559 we
# document =  8 score =  658 0.101797319712 with
# document =  8 score =  661 0.0508986598559 work
# document =  8 score =  668 0.305391959136 you
# document =  8 score =  669 0.152695979568 your
# document =  9 score =  2 0.179605302027 11
# document =  9 score =  11 0.179605302027 2015
# document =  9 score =  13 0.179605302027 21
# document =  9 score =  22 0.179605302027 27
# document =  9 score =  24 0.179605302027 28
# document =  9 score =  37 0.179605302027 5910
# document =  9 score =  47 0.179605302027 able
# document =  9 score =  111 0.179605302027 by
# document =  9 score =  116 0.179605302027 can
# document =  9 score =  128 0.179605302027 cet
# document =  9 score =  142 0.359210604054 clicking
# document =  9 score =  149 0.179605302027 code
# document =  9 score =  218 0.179605302027 error
# document =  9 score =  253 0.179605302027 full
# document =  9 score =  265 0.179605302027 gmail
# document =  9 score =  298 0.359210604054 here
# document =  9 score =  335 0.179605302027 it
# document =  9 score =  385 0.179605302027 message
# document =  9 score =  415 0.179605302027 not
# document =  9 score =  421 0.179605302027 oct
# document =  9 score =  546 0.179605302027 show
# document =  9 score =  600 0.179605302027 to
# document =  9 score =  614 0.179605302027 tue
# document =  9 score =  633 0.179605302027 view
# document =  9 score =  668 0.179605302027 you
# document =  10 score =  8 0.115856889273 1st
# document =  10 score =  11 0.115856889273 2015
# document =  10 score =  16 0.0579284446363 23rd
# document =  10 score =  20 0.0579284446363 26
# document =  10 score =  25 0.0579284446363 2nd
# document =  10 score =  40 0.0579284446363 7th
# document =  10 score =  63 0.0579284446363 all
# document =  10 score =  71 0.0579284446363 and
# document =  10 score =  73 0.0579284446363 any
# document =  10 score =  86 0.0579284446363 authorizations
# document =  10 score =  87 0.0579284446363 authorize
# document =  10 score =  90 0.115856889273 be
# document =  10 score =  94 0.0579284446363 begin
# document =  10 score =  111 0.231713778545 by
# document =  10 score =  113 0.0579284446363 calendar
# document =  10 score =  116 0.115856889273 can
# document =  10 score =  118 0.115856889273 cancel
# document =  10 score =  140 0.115856889273 classes
# document =  10 score =  142 0.115856889273 clicking
# document =  10 score =  176 0.231713778545 credit
# document =  10 score =  181 0.0579284446363 dates
# document =  10 score =  182 0.115856889273 day
# document =  10 score =  201 0.0579284446363 do
# document =  10 score =  214 0.115856889273 edu
# document =  10 score =  223 0.115856889273 exam
# document =  10 score =  228 0.173785333909 fall
# document =  10 score =  236 0.115856889273 final
# document =  10 score =  245 0.0579284446363 for
# document =  10 score =  247 0.115856889273 found
# document =  10 score =  250 0.0579284446363 friday
# document =  10 score =  268 0.0579284446363 going
# document =  10 score =  278 0.0579284446363 had
# document =  10 score =  287 0.115856889273 have
# document =  10 score =  293 0.0579284446363 hello
# document =  10 score =  315 0.0579284446363 if
# document =  10 score =  317 0.0579284446363 important
# document =  10 score =  320 0.0579284446363 in
# document =  10 score =  327 0.115856889273 information
# document =  10 score =  334 0.0579284446363 is
# document =  10 score =  335 0.0579284446363 it
# document =  10 score =  343 0.0579284446363 know
# document =  10 score =  345 0.115856889273 last
# document =  10 score =  352 0.0579284446363 let
# document =  10 score =  366 0.115856889273 luther
# document =  10 score =  394 0.0579284446363 monday
# document =  10 score =  413 0.115856889273 no
# document =  10 score =  422 0.115856889273 october
# document =  10 score =  424 0.0579284446363 of
# document =  10 score =  426 0.115856889273 office
# document =  10 score =  428 0.289642223182 on
# document =  10 score =  439 0.0579284446363 order
# document =  10 score =  465 0.115856889273 please
# document =  10 score =  492 0.0579284446363 questions
# document =  10 score =  502 0.231713778545 registrar
# document =  10 score =  503 0.115856889273 registration
# document =  10 score =  531 0.115856889273 schedule
# document =  10 score =  538 0.115856889273 semester
# document =  10 score =  541 0.0579284446363 september
# document =  10 score =  560 0.0579284446363 stop
# document =  10 score =  578 0.115856889273 term
# document =  10 score =  582 0.0579284446363 thank
# document =  10 score =  585 0.347570667818 the
# document =  10 score =  588 0.0579284446363 then
# document =  10 score =  593 0.0579284446363 this
# document =  10 score =  600 0.289642223182 to
# document =  10 score =  601 0.115856889273 today
# document =  10 score =  619 0.115856889273 under
# document =  10 score =  624 0.0579284446363 us
# document =  10 score =  642 0.0579284446363 website
# document =  10 score =  644 0.115856889273 week
# document =  10 score =  647 0.0579284446363 weeks
# document =  10 score =  663 0.0579284446363 would
# document =  10 score =  668 0.173785333909 you
# document =  11 score =  1 0.0621369766001 100
# document =  11 score =  8 0.0621369766001 1st
# document =  11 score =  51 0.0621369766001 achieve
# document =  11 score =  63 0.0621369766001 all
# document =  11 score =  71 0.1242739532 and
# document =  11 score =  77 0.0621369766001 arms
# document =  11 score =  82 0.0621369766001 at
# document =  11 score =  88 0.0621369766001 back
# document =  11 score =  90 0.0621369766001 be
# document =  11 score =  109 0.0621369766001 but
# document =  11 score =  125 0.0621369766001 ceiling
# document =  11 score =  133 0.0621369766001 chest
# document =  11 score =  134 0.0621369766001 child
# document =  11 score =  139 0.1864109298 class
# document =  11 score =  146 0.0621369766001 closer
# document =  11 score =  148 0.0621369766001 coach
# document =  11 score =  179 0.0621369766001 danielle
# document =  11 score =  182 0.0621369766001 day
# document =  11 score =  201 0.1864109298 do
# document =  11 score =  205 0.0621369766001 down
# document =  11 score =  238 0.0621369766001 find
# document =  11 score =  240 0.1242739532 flat
# document =  11 score =  241 0.0621369766001 floor
# document =  11 score =  252 0.0621369766001 from
# document =  11 score =  267 0.0621369766001 goals
# document =  11 score =  282 0.0621369766001 hamstrings
# document =  11 score =  286 0.0621369766001 hate
# document =  11 score =  287 0.1242739532 have
# document =  11 score =  288 0.0621369766001 having
# document =  11 score =  293 0.0621369766001 hello
# document =  11 score =  297 0.0621369766001 her
# document =  11 score =  301 0.1242739532 home
# document =  11 score =  304 0.0621369766001 homework
# document =  11 score =  308 0.0621369766001 how
# document =  11 score =  309 0.0621369766001 however
# document =  11 score =  315 0.0621369766001 if
# document =  11 score =  316 0.0621369766001 ill
# document =  11 score =  334 0.0621369766001 is
# document =  11 score =  340 0.0621369766001 keeping
# document =  11 score =  351 0.2485479064 leg
# document =  11 score =  354 0.0621369766001 lie
# document =  11 score =  367 0.0621369766001 lynch
# document =  11 score =  400 0.0621369766001 morning
# document =  11 score =  408 0.0621369766001 need
# document =  11 score =  415 0.0621369766001 not
# document =  11 score =  417 0.0621369766001 notice
# document =  11 score =  428 0.2485479064 on
# document =  11 score =  430 0.1242739532 one
# document =  11 score =  437 0.0621369766001 opposite
# document =  11 score =  440 0.0621369766001 other
# document =  11 score =  442 0.1242739532 out
# document =  11 score =  461 0.0621369766001 pilates
# document =  11 score =  487 0.0621369766001 pull
# document =  11 score =  493 0.0621369766001 raise
# document =  11 score =  535 0.0621369766001 see
# document =  11 score =  558 0.0621369766001 stay
# document =  11 score =  562 0.0621369766001 stretch
# document =  11 score =  573 0.0621369766001 take
# document =  11 score =  581 0.0621369766001 than
# document =  11 score =  584 0.0621369766001 that
# document =  11 score =  585 0.310684883001 the
# document =  11 score =  591 0.0621369766001 things
# document =  11 score =  593 0.1242739532 this
# document =  11 score =  597 0.0621369766001 tighter
# document =  11 score =  600 0.434958836201 to
# document =  11 score =  602 0.0621369766001 tomorrow
# document =  11 score =  604 0.0621369766001 towards
# document =  11 score =  623 0.0621369766001 up
# document =  11 score =  626 0.0621369766001 use
# document =  11 score =  637 0.0621369766001 want
# document =  11 score =  641 0.0621369766001 we
# document =  11 score =  643 0.0621369766001 wednesday
# document =  11 score =  652 0.0621369766001 while
# document =  11 score =  653 0.1242739532 will
# document =  11 score =  658 0.0621369766001 with
# document =  11 score =  664 0.0621369766001 write
# document =  11 score =  668 0.310684883001 you
# document =  11 score =  669 0.2485479064 your
# document =  12 score =  9 0.084818892968 20
# document =  12 score =  10 0.084818892968 201
# document =  12 score =  26 0.169637785936 30
# document =  12 score =  44 0.084818892968 90
# document =  12 score =  56 0.084818892968 advance
# document =  12 score =  63 0.084818892968 all
# document =  12 score =  70 0.084818892968 an
# document =  12 score =  71 0.169637785936 and
# document =  12 score =  72 0.084818892968 annual
# document =  12 score =  76 0.084818892968 are
# document =  12 score =  82 0.084818892968 at
# document =  12 score =  83 0.084818892968 attend
# document =  12 score =  90 0.084818892968 be
# document =  12 score =  106 0.084818892968 break
# document =  12 score =  108 0.084818892968 business
# document =  12 score =  127 0.084818892968 ceo
# document =  12 score =  147 0.169637785936 club
# document =  12 score =  156 0.084818892968 competition
# document =  12 score =  160 0.084818892968 conference
# document =  12 score =  180 0.084818892968 date
# document =  12 score =  196 0.084818892968 did
# document =  12 score =  215 0.084818892968 elevator
# document =  12 score =  219 0.084818892968 even
# document =  12 score =  222 0.169637785936 everyone
# document =  12 score =  224 0.084818892968 exciting
# document =  12 score =  228 0.084818892968 fall
# document =  12 score =  246 0.084818892968 forward
# document =  12 score =  274 0.084818892968 great
# document =  12 score =  278 0.084818892968 had
# document =  12 score =  292 0.084818892968 held
# document =  12 score =  299 0.084818892968 hi
# document =  12 score =  302 0.084818892968 homecoming
# document =  12 score =  305 0.084818892968 hope
# document =  12 score =  313 0.084818892968 idea
# document =  12 score =  315 0.169637785936 if
# document =  12 score =  320 0.254456678904 in
# document =  12 score =  329 0.084818892968 interested
# document =  12 score =  334 0.169637785936 is
# document =  12 score =  341 0.084818892968 kind
# document =  12 score =  349 0.084818892968 leake
# document =  12 score =  361 0.084818892968 looking
# document =  12 score =  366 0.084818892968 luther
# document =  12 score =  382 0.169637785936 meeting
# document =  12 score =  415 0.169637785936 not
# document =  12 score =  416 0.084818892968 note
# document =  12 score =  422 0.084818892968 october
# document =  12 score =  427 0.084818892968 olin
# document =  12 score =  433 0.084818892968 open
# document =  12 score =  441 0.084818892968 our
# document =  12 score =  462 0.084818892968 pitch
# document =  12 score =  463 0.084818892968 pitching
# document =  12 score =  465 0.084818892968 please
# document =  12 score =  499 0.084818892968 regards
# document =  12 score =  500 0.084818892968 register
# document =  12 score =  513 0.084818892968 representing
# document =  12 score =  520 0.084818892968 richard
# document =  12 score =  522 0.084818892968 room
# document =  12 score =  534 0.084818892968 seconds
# document =  12 score =  536 0.084818892968 seeing
# document =  12 score =  585 0.169637785936 the
# document =  12 score =  593 0.339275571872 this
# document =  12 score =  599 0.084818892968 time
# document =  12 score =  600 0.169637785936 to
# document =  12 score =  602 0.084818892968 tomorrow
# document =  12 score =  615 0.084818892968 tuesday
# document =  12 score =  627 0.084818892968 usual
# document =  12 score =  631 0.084818892968 venue
# document =  12 score =  645 0.084818892968 weekend
# document =  12 score =  653 0.084818892968 will
# document =  12 score =  666 0.084818892968 year
# document =  12 score =  668 0.339275571872 you
# document =  13 score =  6 0.0367607311047 1997
# document =  13 score =  11 0.0735214622094 2015
# document =  13 score =  19 0.110282193314 250
# document =  13 score =  26 0.0735214622094 30
# document =  13 score =  32 0.0367607311047 44
# document =  13 score =  35 0.0735214622094 500
# document =  13 score =  45 0.0367607311047 94104
# document =  13 score =  50 0.0367607311047 account
# document =  13 score =  53 0.0367607311047 addition
# document =  13 score =  57 0.0367607311047 advertisement
# document =  13 score =  63 0.0735214622094 all
# document =  13 score =  89 0.0367607311047 background
# document =  13 score =  90 0.0735214622094 be
# document =  13 score =  91 0.0367607311047 because
# document =  13 score =  105 0.0735214622094 bonusmail
# document =  13 score =  112 0.0367607311047 ca
# document =  13 score =  116 0.0367607311047 can
# document =  13 score =  131 0.0367607311047 check
# document =  13 score =  141 0.183803655523 click
# document =  13 score =  145 0.0367607311047 close
# document =  13 score =  151 0.0367607311047 com
# document =  13 score =  158 0.0367607311047 completing
# document =  13 score =  162 0.0367607311047 consent
# document =  13 score =  177 0.0367607311047 credited
# document =  13 score =  183 0.0735214622094 days
# document =  13 score =  201 0.0367607311047 do
# document =  13 score =  206 0.0735214622094 drive
# document =  13 score =  207 0.0367607311047 driver
# document =  13 score =  210 0.0735214622094 earn
# document =  13 score =  211 0.0367607311047 earned
# document =  13 score =  216 0.110282193314 email
# document =  13 score =  226 0.0367607311047 expires
# document =  13 score =  239 0.0367607311047 first
# document =  13 score =  245 0.0735214622094 for
# document =  13 score =  248 0.0367607311047 francisco
# document =  13 score =  252 0.0367607311047 from
# document =  13 score =  259 0.0367607311047 get
# document =  13 score =  298 0.183803655523 here
# document =  13 score =  315 0.110282193314 if
# document =  13 score =  320 0.110282193314 in
# document =  13 score =  321 0.0367607311047 inc
# document =  13 score =  360 0.0735214622094 longer
# document =  13 score =  370 0.0367607311047 make
# document =  13 score =  383 0.0367607311047 member
# document =  13 score =  386 0.0367607311047 midnight
# document =  13 score =  396 0.0367607311047 montgomery
# document =  13 score =  404 0.110282193314 must
# document =  13 score =  405 0.183803655523 mypoints
# document =  13 score =  413 0.0735214622094 no
# document =  13 score =  415 0.0735214622094 not
# document =  13 score =  416 0.0367607311047 note
# document =  13 score =  418 0.0367607311047 november
# document =  13 score =  424 0.110282193314 of
# document =  13 score =  425 0.0735214622094 offer
# document =  13 score =  429 0.0367607311047 once
# document =  13 score =  431 0.0735214622094 online
# document =  13 score =  432 0.0367607311047 only
# document =  13 score =  439 0.0735214622094 order
# document =  13 score =  451 0.0367607311047 partner
# document =  13 score =  465 0.220564386628 please
# document =  13 score =  466 0.0367607311047 point
# document =  13 score =  467 0.330846579942 points
# document =  13 score =  469 0.0367607311047 policy
# document =  13 score =  473 0.0735214622094 privacy
# document =  13 score =  486 0.0367607311047 pt
# document =  13 score =  495 0.0367607311047 re
# document =  13 score =  497 0.220564386628 receive
# document =  13 score =  498 0.0367607311047 received
# document =  13 score =  500 0.0735214622094 register
# document =  13 score =  501 0.0735214622094 registering
# document =  13 score =  511 0.0367607311047 reply
# document =  13 score =  517 0.0367607311047 reserved
# document =  13 score =  521 0.0367607311047 rights
# document =  13 score =  526 0.0367607311047 san
# document =  13 score =  554 0.0367607311047 st
# document =  13 score =  556 0.0367607311047 statement
# document =  13 score =  565 0.0367607311047 suite
# document =  13 score =  585 0.0735214622094 the
# document =  13 score =  593 0.220564386628 this
# document =  13 score =  600 0.477889504361 to
# document =  13 score =  605 0.0367607311047 transaction
# document =  13 score =  612 0.0367607311047 trip
# document =  13 score =  617 0.0367607311047 uber
# document =  13 score =  622 0.0735214622094 unsubscribe
# document =  13 score =  630 0.0367607311047 ve
# document =  13 score =  633 0.0735214622094 view
# document =  13 score =  634 0.0367607311047 visit
# document =  13 score =  653 0.0735214622094 will
# document =  13 score =  657 0.110282193314 wish
# document =  13 score =  659 0.0735214622094 within
# document =  13 score =  668 0.330846579942 you
# document =  13 score =  669 0.147042924419 your

# %%
wordList = vectorizer.get_feature_names()   
wordList[104:110]
# Out:
# ['bombs', 'bonusmail', 'break', 'broad', 'business', 'but']

# %%
#look at raw documents and then print out all of the non-zer entries in 
#that row of the matrx
bd.data[3]
# Out:
# b'\xef\xbb\xbfHello,\xc2\xa0\n\nI have over 5 years of transcription experience and have been supporting several clients with their transcription requirements. I assure you of quality work and most importantly confidentiality of all the proprietary information / materials. All the work is deleted from our systems as soon as the transcription is completed to the satisfaction of our client.\xc2\xa0\n\nI do sign an NDA if so required. I offer a very low rate of USD 0.60 per audio minute and audios can be transcribed and returned within 24-48 hrs time. What I can also do is a sample transcript and if the sample is to your satisfaction, then we can take it forward from there.\n\nPayment can be made only if you are satisfied with the work and the payment mode could be PayPal, wire transfer or any other means as per your convenience. Let me know what is a good time to call you and discuss this further.\xc2\xa0\n\nLooking forward to hearing from you soon and working for you and once again I assure you of quality work and confidentiality of information.\xc2\xa0\n\nRegards,\xc2\xa0\nGina Smith\n'

# %%
#Word frequency value for a particular word in a particular document
wordList = vectorizer.get_feature_names()
wordList = [w for w in wordList if not w in ENGLISH_STOP_WORDS]
#len(wordList)#549

# %%
for i in range(len(wordList)):
    if(X[3,i] != 0.0):
        print(wordList[i])
# Out:
# 24
# 48
# 60
# aid
# american
# annual
# assistant
# assure
# audio
# authorize
# begin
# best
# billions
# bills
# business
# ca
# choose
# city
# contact
# continue
# date
# deadline
# department
# did
# email
# fall
# fax
# giving
# hate
# having
# help
# hk
# hosting
# important
# keeping
# kyle
# launch
# love
# make
# materials
# members
# mode
# modeling
# mypoints
# november
# open
# opposite
# paid
# pay
# phone
# pieces
# possible
# privacy
# programs
# pumpkin
# released
# reminder
# reply
# required
# richard
# room
# rooms
# sample
# seeing
# semester
# sent
# t2x
# testing
# things
# today
# unaware
# understanding
# usd
# view
# walking
# wan
# write
# year

# %%
#idx = wordList.index('fax')
#idx
#finding idx
def search_word(sen):
    words = sen.split()
    #print(words)
    prevword = []
    for w in words:
        if w in wordList:
            prevword.append(w)
    return prevword

# %%
def find_idx(wordarray):
    #print(wordarray)
    idxarray = []
    for word in wordarray:
        idx = wordList.index(word)
        idxarray.append(idx)
    return idxarray

# %%
def find_class(idxarray):
    class_hs = {} #dictionay of class and probability
    class_score = []
    for j in idxarray:#finding words in all docs
        for i in range(14): 
            #print(j)
            if(X[i,j] != 0.0):
                c_hs = bd.target_names[bd.target[i]]#class for the ith doc
                score = X[i,j]
                t = c_hs,score,j
                #print(c_hs)
                #print(score)
                #class_hs[c_hs] = score
                
                class_score.append(t)
    return class_score
    #if X[i,201] != 0.0:
        #print("fax appears in document", i,"with score",X[i,idx])
#finding index of words

# %%
def ham_prob(hammy):
    ham_idx = []
    for i in hammy:
        ham_idx.append(i[2])
    #print(ham_idx)
    prob = 1
    for i in range(14):    
        for j in range(550):
            if (j not in ham_idx) and (bd.target_names[bd.target[i]] == 'ham') and (X[i,j] != 0.0):
                dif = (1-(X[i,j]))
                #print("dif = ", dif)
                prob *= dif
                
    for i in ham_idx:
        prob *= i
    return prob

# %%
def spam_prob(spammy):
    spam_idx = []
    for i in spammy:
        spam_idx.append(i[2])
    #print(spam_idx)
    prob = 1
    for i in range(14):    
        for j in range(550):
            if (j not in spam_idx) and (bd.target_names[bd.target[i]] == 'spam') and (X[i,j] != 0.0):
                dif = (1-(X[i,j]))
                #print("dif = ", dif)
                prob *= dif
                
    for i in spam_idx:
        prob *= i
    return prob

# %%
word_array = search_word("I would like to work in the web development project")
#word_array

# %%
idx_array = find_idx(word_array)
#idx_array

# %%
cs_tuple = find_class(idx_array)
#cs_tuple
hammy = []
spammy = []
for i in cs_tuple:
    if (i[0] == 'ham'):
        hammy.append(i)
    #print(hammy)
    else:
        spammy.append(i)
#print(hammy)
        
h_prob = ham_prob(hammy)
s_prob = spam_prob(spammy)

#prior probability for ham is .20 and spam is .80
ham = (h_prob*.20)/((h_prob*.20)+(s_prob*.80)) 
#ham
spam = (s_prob*.80)/((s_prob*.80)+(h_prob*.20))
#spam

# %%
print("Ham probability is : %.5f" %ham)
print("Spam probability is : %.5f" %spam)
if(spam > ham):
    print("The email is spam")
else:
    print("The email is ham.")
# Out:
# Ham probability is : 0.99681
# Spam probability is : 0.00319
# The email is ham.

# %%
word_array = search_word("You can view it by clicking here")

# %%
idx_array = find_idx(word_array)
#idx_array

# %%
cs_tuple = find_class(idx_array)
#cs_tuple
hammy = []
spammy = []
for i in cs_tuple:
    if (i[0] == 'ham'):
        hammy.append(i)
    #print(hammy)
    else:
        spammy.append(i)
#print(hammy)
        
h_prob = ham_prob(hammy)
s_prob = spam_prob(spammy)

#prior probability for both ham is .20 and spam is .80
ham = (h_prob*.20)/((h_prob*.20)+(s_prob*.80)) 
#ham
spam = (s_prob*.80)/((s_prob*.80)+(h_prob*.20))
#spam

# %%
print("Ham probability is : %.5f" %ham)
print("Spam probability is : %.5f" %spam)
if(spam > ham):
    print("The email is spam")
else:
    print("The email is ham.")
# Out:
# Ham probability is : 0.00004
# Spam probability is : 0.99996
# The email is spam

# %%
#vectorizer.inverse_transform(X)[3]

# %%
#data_path = os.path.abspath(os.path.join('baise_spamfilter'))
#spam_path = os.path.join(data_path,'spam')
#ham_path = os.path.join(data_path,'ham')

# %%
#def get_msg(path):
    #with open(path) as con:
        #msg = con.readlines()
        #return ''.join(msg)
